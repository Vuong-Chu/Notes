# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
rng = np.random.default_rng(123456)
x = np.random.random((10,1))
x = np.concatenate((np.zeros((10,1)),x),axis=1) #np.c_[a,b], np.column_stack((a,d)), np.hstack((a,b))
y = np.random.random(10)
print(x)
# Out:
# [[0.         0.52592477]
#  [0.         0.49917341]
#  [0.         0.40228166]
#  [0.         0.36032819]
#  [0.         0.25504948]
#  [0.         0.57288589]
#  [0.         0.83419137]
#  [0.         0.68705742]
#  [0.         0.97891355]
#  [0.         0.13502782]]

# %%
lr = LinearRegression(normalize=True)
lr.fit(x,y)
values = np.random.random((3,2))
lr.predict(values)
# Out:
# array([0.53147716, 0.63808312, 0.45543057])
